# %%
import tensorflow as tf
import numpy as np
import librosa.display, os
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def create_spectrogram(audio_file, image_file):
    # Adjust figure size if needed
    fig = plt.figure(figsize=(8, 6))  # You can adjust the figure size as needed
    ax = fig.add_subplot(1, 1, 1)
    fig.subplots_adjust(left=0, right=1, bottom=0, top=1)

    # Load audio file
    y, sr = librosa.load(audio_file)

    # Compute mel spectrogram
    # Adjust parameters such as n_fft, hop_length, and n_mels for better resolution
    # You may also experiment with window type (e.g., window='hann') and other parameters
    ms = librosa.feature.melspectrogram(y=y, sr=sr, n_fft=2048, hop_length=512, n_mels=128)

    # Convert power to decibels (log scale)
    log_ms = librosa.power_to_db(ms, ref=np.max)

    # Display the mel spectrogram
    librosa.display.specshow(log_ms, sr=sr, x_axis='time', y_axis='mel')

    # Add color bar for intensity scale (optional)
    plt.colorbar(format='%+2.0f dB')

    # Save the spectrogram as an image file
    fig.savefig(image_file, bbox_inches='tight')  # Use bbox_inches='tight' to prevent clipping
    plt.close(fig)

# %%
def create_pngs_from_wavs(input_path, output_path):
    if not os.path.exists(output_path):
        os.makedirs(output_path)

    dir = os.listdir(input_path)

    for i, file in enumerate(dir):
        if not file.endswith('.wav'):
            continue  # Skip non-WAV files

        input_file = os.path.join(input_path, file)
        output_file = os.path.join(output_path, file.replace('.wav', '.png'))
        create_spectrogram(input_file, output_file)

# %%
create_pngs_from_wavs('Datasets/Augment_New/AK-12', 'Spectrograms_New/AK-12')

# %%
create_pngs_from_wavs('Datasets/Augment_New/AK-47', 'Spectrograms_New/AK-47')

# %%
create_pngs_from_wavs('Datasets/Augment_New/IMI Desert Eagle', 'Spectrograms_New/IMI Desert Eagle')

# %%
create_pngs_from_wavs('Datasets/Augment_New/M16', 'Spectrograms_New/M16')

# %%
create_pngs_from_wavs('Datasets/Augment_New/M249', 'Spectrograms_New/M249')

# %%
create_pngs_from_wavs('Datasets/Augment_New/M4', 'Spectrograms_New/M4')

# %%
create_pngs_from_wavs('Datasets/Augment_New/MG-42', 'Spectrograms_New/MG-42')

# %%
create_pngs_from_wavs('Datasets/Augment_New/MP5', 'Spectrograms_New/MP5')

# %%
create_pngs_from_wavs('Datasets/Augment_New/Zastava M92', 'Spectrograms_New/Zastava M92')

# %%
create_pngs_from_wavs('Datasets/Augment_New/NonGunshots', 'Spectrograms_New/NonGunshots')

# %%
import os
from keras.preprocessing import image

def load_images_from_path(path, label):
    images = []
    labels = []
    for file in os.listdir(path):
        # Ignore directories
        if os.path.isfile(os.path.join(path, file)):
            images.append(image.img_to_array(image.load_img(os.path.join(path, file), target_size=(224, 224, 3))))
            labels.append(label)
    return images, labels

def show_images(images):
    fig, axes = plt.subplots(1, 8, figsize=(20, 20), subplot_kw={'xticks': [], 'yticks': []})

    for i, ax in enumerate(axes.flat):
        ax.imshow(images[i] / 255)
        
x = []
y = []

# %%
images, labels = load_images_from_path('Spectrograms_New/AK-12', 0)
show_images(images)
    
x += images
y += labels

# %%
images, labels = load_images_from_path('Spectrograms_New/AK-47', 1)
show_images(images)
    
x += images
y += labels

# %%
images, labels = load_images_from_path('Spectrograms_New/IMI Desert Eagle', 2)
show_images(images)
    
x += images
y += labels

# %%
images, labels = load_images_from_path('Spectrograms_New/M16', 3)
show_images(images)
    
x += images
y += labels

# %%
images, labels = load_images_from_path('Spectrograms_New/M249', 4)
show_images(images)
    
x += images
y += labels

# %%
images, labels = load_images_from_path('Spectrograms_New/M4', 5)
show_images(images)
    
x += images
y += labels

# %%
images, labels = load_images_from_path('Spectrograms_New/MG-42', 6)
show_images(images)
    
x += images
y += labels

# %%
images, labels = load_images_from_path('Spectrograms_New/MP5', 7)
show_images(images)
    
x += images
y += labels

# %%
images, labels = load_images_from_path('Spectrograms_New/Zastava M92', 8)
show_images(images)
    
x += images
y += labels

# %%
images, labels = load_images_from_path('Spectrograms_New/NonGunshots', 9)
show_images(images)
    
x += images
y += labels

# %%
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, stratify=y, test_size=0.3, random_state=0)

x_train_norm = np.array(x_train) / 255
x_test_norm = np.array(x_test) / 255

y_train_encoded = to_categorical(y_train)
y_test_encoded = to_categorical(y_test)

# %% [markdown]
# # Training

# %%
#CNN Layer

from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Flatten, Dense

model = Sequential()
model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(224, 224, 3)))
model.add(MaxPooling2D(2, 2))
model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(MaxPooling2D(2, 2))
model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(MaxPooling2D(2, 2))
model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(MaxPooling2D(2, 2))
model.add(Flatten())
model.add(Dense(1024, activation='relu'))
model.add(Dense(10, activation='softmax'))
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# /Users/shazanadiatulhudamohdsalleh/anaconda3/lib/python3.11/site-packages/keras/src/layers/convolutional/base_conv.py:99: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 222, 222, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 111, 111, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 109, 109, 128)  │        36,992 │
# ...

# %%
hist = model.fit(x_train_norm, y_train_encoded, validation_data=(x_test_norm, y_test_encoded),
                 batch_size=10,epochs=15)
# Out:
# Epoch 1/15
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 358s 455ms/step - accuracy: 0.2783 - loss: 1.9514 - val_accuracy: 0.6783 - val_loss: 0.8387
# Epoch 2/15
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 375s 478ms/step - accuracy: 0.7337 - loss: 0.6899 - val_accuracy: 0.7885 - val_loss: 0.5325
# Epoch 3/15
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 459s 585ms/step - accuracy: 0.8407 - loss: 0.3593 - val_accuracy: 0.8281 - val_loss: 0.3846
# Epoch 4/15
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 468s 596ms/step - accuracy: 0.8860 - loss: 0.2591 - val_accuracy: 0.8183 - val_loss: 0.4202
# Epoch 5/15
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 559s 713ms/step - accuracy: 0.9065 - loss: 0.1989 - val_accuracy: 0.8427 - val_loss: 0.3564
# Epoch 6/15
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 548s 699ms/step - accuracy: 0.9224 - loss: 0.1777 - val_accuracy: 0.8454 - val_loss: 0.3666
# Epoch 7/15
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 573s 731ms/step - accuracy: 0.9369 - loss: 0.1569 - val_accuracy: 0.8555 - val_loss: 0.4235
# Epoch 8/15
# ...

# %%
import numpy as np

# Get predictions
y_test_pred = model.predict(x_test_norm)
y_test_pred_classes = np.argmax(y_test_pred, axis=1)
y_test_true_classes = np.argmax(y_test_encoded, axis=1)
# Out:
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 43s 411ms/step

# %%
from sklearn.metrics import precision_score, recall_score, f1_score

# Calculate precision, recall, and F1 score after train the model
precision = precision_score(y_test_true_classes, y_test_pred_classes, average='weighted')
recall = recall_score(y_test_true_classes, y_test_pred_classes, average='weighted')
f1 = f1_score(y_test_true_classes, y_test_pred_classes, average='weighted')

print(f'Precision: {precision}')
print(f'Recall: {recall}')
print(f'F1 Score: {f1}')
# Out:
# Precision: 0.8059629315684472
# Recall: 0.8004170390229371
# F1 Score: 0.7996355225367924

# %%
acc = hist.history['accuracy']
val_acc = hist.history['val_accuracy']
epochs = range(1, len(acc) + 1)

plt.plot(epochs, acc, '-', label='Training Accuracy')
plt.plot(epochs, val_acc, ':', label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
plt.plot()
# Out:
# []

# %% [markdown]
# # Transfer learning

# %%
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.applications.mobilenet import preprocess_input

base_model = MobileNetV2(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

x_train_norm = preprocess_input(np.array(x_train))
x_test_norm = preprocess_input(np.array(x_test))

train_features = base_model.predict(x_train_norm)
test_features = base_model.predict(x_test_norm)
# Out:
#  21/245 ━━━━━━━━━━━━━━━━━━━━ 1:09 312ms/step

# %%
from keras.models import Sequential
from keras.layers import Flatten, Dense, Input

model = Sequential()
model.add(Input(shape=train_features.shape[1:]))
model.add(Flatten())
model.add(Dense(1024, activation='relu'))
model.add(Dense(10, activation='softmax'))
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
hist = model.fit(train_features, y_train_encoded, validation_data=(test_features, y_test_encoded),
                 batch_size=10, epochs=15)

# %%
acc = hist.history['accuracy']
val_acc = hist.history['val_accuracy']
epochs = range(1, len(acc) + 1)

plt.plot(epochs, acc, '-', label='Training Accuracy')
plt.plot(epochs, val_acc, ':', label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
plt.plot()

# %%
import numpy as np

# Get predictions
y_predicted = model.predict(test_features)
y_pred_classes = np.argmax(y_predicted, axis=1)
y_true_classes = np.argmax(y_test_encoded, axis=1)

# %%
# Calculate precision, recall, and F1 score after Fine Tuning the model.
precision = precision_score(y_true_classes, y_pred_classes, average='weighted')
recall = recall_score(y_true_classes, y_pred_classes, average='weighted')
f1 = f1_score(y_true_classes, y_pred_classes, average='weighted')

print(f'Precision: {precision}')
print(f'Recall: {recall}')
print(f'F1 Score: {f1}')

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
sns.set()

y_predicted = model.predict(test_features)
mat = confusion_matrix(y_test_encoded.argmax(axis=1), y_predicted.argmax(axis=1))
class_labels = ['AK-12','AK-47','IMI Desert Eagle','M16','M249','M4','MG-42','MP5','Zastava M92','NonGunshots']

sns.heatmap(mat, square=True, annot=True, fmt='d', cbar=False, cmap='Blues',
            xticklabels=class_labels,
            yticklabels=class_labels)

plt.xlabel('Predicted label')
plt.ylabel('Actual label')
plt.show()

# %%
model.save('/Users/shazanadiatulhudamohdsalleh/fyp/RecognitionSystem/model_new.keras')

# %%
model.save('/Users/shazanadiatulhudamohdsalleh/fyp/RecognitionSystem/model_new.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %% [markdown]
# # Testing

# %%
create_spectrogram('Samples/WAV/Sample2.wav','Samples/Spectrograms/Sample2.png')

x = image.load_img('Samples/Spectrograms/Sample2.png', target_size=(224, 224))
plt.xticks([])
plt.yticks([])
plt.imshow(x)

# %%
x = image.img_to_array(x)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

y = base_model.predict(x)
predictions = model.predict(y)

for i, label in enumerate(class_labels):
    print(f'{label}: {predictions[0][i]}')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 870ms/step
# AK-12: 3.7418512732756426e-10
# AK-47: 6.113895506132394e-05
# IMI Desert Eagle: 0.4181097149848938
# M16: 0.192252516746521
# M249: 1.1395532965252642e-05
# M4: 0.3627825975418091
# MG-42: 2.8016798751195893e-05
# MP5: 0.026754606515169144
# Zastava M92: 1.180864386580039e-14
# NonGunshots: 1.0163755254088969e-11
